# %%
# %pip install numpy pandas scipy matplotlib seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# Set random seed for reproducibility
np.random.seed(42)

# Generate a positively skewed dataset (income-like)
data = np.random.exponential(scale=1000, size=1000)  # Exponential distribution is naturally skewed

# Convert to a Pandas Series for easier handling
data_series = pd.Series(data)

# Calculate skewness
skewness = skew(data_series)
print(f"Skewness of the dataset: {skewness:.3f}")

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.histplot(data_series, kde=True, color='blue')
plt.title('Distribution of Synthetic Income Data (Positive Skew)', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
# Out:
# Skewness of the dataset: 1.865

# %%
# Handling Skewness: Log Transformation
# One common way to reduce skewness is by applying a log transformation. This compresses large values and spreads out smaller ones, making the distribution more symmetric. Let’s try it!

# Apply log transformation (add 1 to avoid log(0) errors)
log_data = np.log1p(data_series)

# Calculate new skewness
log_skewness = skew(log_data)
print(f"Skewness after log transformation: {log_skewness:.3f}")

# Plot the transformed distribution
plt.figure(figsize=(10, 6))
sns.histplot(log_data, kde=True, color='green')
plt.title('Distribution After Log Transformation (Reduced Skew)', fontsize=14)
plt.xlabel('Log(Income)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()
# Out:
# Skewness after log transformation: -0.802
